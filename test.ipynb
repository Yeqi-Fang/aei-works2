# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(-3.14, 3.14, 1000)
b = (np.sin(4 * a) / (4 * a + 1e-8)) ** 2

plt.plot(a, b, label='$(\sin(x)/x)^2$')
plt.title('Plot of $(\sin(x)/x)^2$')
plt.xlabel('x')
plt.ylabel('$(\sin(x)/x)^2$')
plt.ylim(0, 1.1)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_10595/1394049863.py:7: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(a, b, label='$(\sin(x)/x)^2$')
# /tmp/ipykernel_10595/1394049863.py:8: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Plot of $(\sin(x)/x)^2$')
# /tmp/ipykernel_10595/1394049863.py:10: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$(\sin(x)/x)^2$')

# %%
c = np.random.uniform(-2.14, 2.14, 10000)

d = 1 - (np.sin(4*c) / (4* c )) ** 2

plt.hist(d, bins=30, density=True, alpha=0.7, label='Histogram of $(\sin(x)/x)^2$')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_10595/160257201.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.hist(d, bins=30, density=True, alpha=0.7, label='Histogram of $(\sin(x)/x)^2$')
# (array([ 1.08900075,  0.36600025,  0.41400028,  0.32100022,  0.25500017,
#          0.24000016,  0.24000016,  0.21900015,  0.22500015,  0.21900015,
#          0.23400016,  0.20100014,  0.24000016,  0.24900017,  0.24000016,
#          0.21300015,  0.25800018,  0.16800012,  0.24000016,  0.22200015,
#          0.20700014,  0.26100018,  0.26700018,  0.2880002 ,  0.31500022,
#          0.31200021,  0.42900029,  0.46500032,  4.72800324, 16.87501158]),
#  array([6.86072755e-07, 3.33339965e-02, 6.66673070e-02, 1.00000617e-01,
#         1.33333928e-01, 1.66667238e-01, 2.00000549e-01, 2.33333859e-01,
#         2.66667170e-01, 3.00000480e-01, 3.33333791e-01, 3.66667101e-01,
# ...

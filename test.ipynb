# %%
import numpy as np
import matplotlib.pyplot as plt

a = np.linspace(-3.14, 3.14, 1000)
b = (np.sin(4 * a) / (4 * a + 1e-8)) ** 2

plt.plot(a, b, label='$(\sin(x)/x)^2$')
plt.title('Plot of $(\sin(x)/x)^2$')
plt.xlabel('x')
plt.ylabel('$(\sin(x)/x)^2$')
plt.ylim(0, 1.1)
plt.show()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1712329/1394049863.py:7: SyntaxWarning: invalid escape sequence '\s'
#   plt.plot(a, b, label='$(\sin(x)/x)^2$')
# /tmp/ipykernel_1712329/1394049863.py:8: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Plot of $(\sin(x)/x)^2$')
# /tmp/ipykernel_1712329/1394049863.py:10: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$(\sin(x)/x)^2$')

# %%
c = np.random.uniform(-3.14, 3.14, 10000)

d = 1 - (np.sin(c) / (c )) ** 2

plt.hist(d, bins=30, density=True, alpha=0.7, label='Histogram of $(\sin(x)/x)^2$')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1712329/3505597285.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.hist(d, bins=30, density=True, alpha=0.7, label='Histogram of $(\sin(x)/x)^2$')
# (array([2.90700141, 1.27200062, 0.97200047, 0.92100045, 0.69300034,
#         0.77400037, 0.6240003 , 0.72900035, 0.60600029, 0.56400027,
#         0.67500033, 0.6120003 , 0.64500031, 0.60000029, 0.53700026,
#         0.58800028, 0.59100029, 0.67200033, 0.63900031, 0.71100034,
#         0.73200035, 0.66600032, 0.75300036, 0.77100037, 0.88500043,
#         0.88800043, 1.08600053, 1.29300063, 1.77900086, 4.81500233]),
#  array([2.18889431e-07, 3.33335361e-02, 6.66668533e-02, 1.00000171e-01,
#         1.33333488e-01, 1.66666805e-01, 2.00000122e-01, 2.33333439e-01,
#         2.66666757e-01, 3.00000074e-01, 3.33333391e-01, 3.66666708e-01,
#         4.00000025e-01, 4.33333343e-01, 4.66666660e-01, 4.99999977e-01,
#         5.33333294e-01, 5.66666611e-01, 5.99999929e-01, 6.33333246e-01,
#         6.66666563e-01, 6.99999880e-01, 7.33333197e-01, 7.66666515e-01,
#         7.99999832e-01, 8.33333149e-01, 8.66666466e-01, 8.99999783e-01,
#         9.33333101e-01, 9.66666418e-01, 9.99999735e-01]),
#  <BarContainer object of 30 artists>)
